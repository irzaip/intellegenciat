# %%
f = open('954kata_indo.txt')

# %%
a = f.readlines()

# %%
f.close()

# %%
mydic = []
proc = []
for input in a:
    baris = input
    proc = baris.split("(")
    an = proc[1].split("):")
    proc[1]=an.pop()
    proc.append(an.pop())
    print proc
    mydic.append(proc)
# Out:
# ['abrasi ', ' Penyimpangan dari yang umum / tidak wajar\n', 'aberasi']
# ['absorsi ', ' penyerapan / penghisapan\n', 'absorpsi']
# ['accu ', ' alat himpun tenaga listrik\n', 'aki']
# ['adap ', ' moral / etika / sopan-santun\n', 'adab']
# ['adegio ', ' waktu perlahan-lahan, tetapi berekspresi tinggi\n', 'adagio']
# ['adesi ', ' bersifat melekat\n', 'adhesi']
# ['adi busana ', ' busana yang dirancang secara ekslusif / busana kebesaran\n', 'adibusana']
# ['adi daya ', ' adikuasa / super power / negara Amerika Serikat\n', 'adidaya']
# ['adi gang ', ' bersifat pamer kekuasaan dan kekuatan\n', 'adigang']
# ['adi guna ', ' bersifat pamer kepandaian\n', 'adiguna']
# ['adi gung ', ' bersifat pamer keluhuran atau keturunan\n', 'adigung']
# ['adi kodrati ', ' kekuatan dari Tuhan\n', 'adikodrati']
# ['adi luhung ', ' luhur dan bermutu tinggi\n', 'adiluhung']
# ['aditorium/oditorium ', ' ruang untuk mendengarkan ceramah / ruang pertunjukan\n', 'auditorium']
# ...

# %%
proc
# Out:
# ['zygot/zigote ',
#  ' perkembangan lanjut pertemuan sel jantan dan betina / sebelum menjadi embrio',
#  'zigot']

# %%
proc
# Out:
# ['zygot/zigote ',
#  ' perkembangan lanjut pertemuan sel jantan dan betina / sebelum menjadi embrio',
#  'zigot']

# %%
for a in mydic:
    a[0]=a[0].strip()
    a[1]=a[1].strip()
    a[2]=a[2].strip()

# %%
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-134-467adec87bc0> in <module>()
# ----> 1 conn
#
# NameError: name 'conn' is not defined
